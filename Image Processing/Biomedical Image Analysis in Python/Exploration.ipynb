# %% [markdown]
# #### Loading images
#
# - `imageio`: read and save images
# - `Image` objects are NumPy arrays

# %%
pip install imageio
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import imageio
im = imageio.v2.imread('chest-220.dcm')
type(im)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_13976\4167228516.py:2: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   im = imageio.imread('chest-220.dcm')
# imageio.core.util.Array

# %%
im
# Out:
# Array([[-1000, -1000, -1000, ..., -1000, -1000, -1000],
#        [-1000, -1000, -1000, ..., -1000, -1000, -1000],
#        [-1000, -1000, -1000, ..., -1000, -1000, -1000],
#        ...,
#        [-1000, -1000, -1000, ..., -1000, -1000, -1000],
#        [-1000, -1000, -1000, ..., -1000, -1000, -1000],
#        [-1000, -1000, -1000, ..., -1000, -1000, -1000]], dtype=int16)

# %% [markdown]
# #### Loading images
# - Slice the array by specifying values along each available dimension
#
# #### Metadata
# - Metadata: the who, what, when, where and how of iamge acquisition
# - Accessible in `Image` objects through the `meta` dictionary attribute

# %%
im.meta
# Out:
# Dict([('TransferSyntaxUID', '1.2.840.10008.1.2'),
#       ('SOPClassUID', '1.2.840.10008.5.1.4.1.1.2'),
#       ('SOPInstanceUID',
#        '1.3.6.1.4.1.14519.5.2.1.5168.1900.290866807370146801046392918286'),
#       ('StudyDate', '20040529'),
#       ('SeriesDate', '20040515'),
#       ('ContentDate', '20040515'),
#       ('StudyTime', '115208'),
#       ('SeriesTime', '115254'),
#       ('ContentTime', '115325'),
#       ('Modality', 'CT'),
#       ('Manufacturer', 'GE MEDICAL SYSTEMS'),
#       ('StudyDescription', 'PET CT with registered MR'),
#       ('SeriesDescription', 'CT IMAGES - RESEARCH'),
#       ('PatientName', 'STS_007'),
#       ('PatientID', 'STS_007'),
#       ('PatientBirthDate', ''),
#       ('PatientSex', 'F '),
#       ('PatientWeight', 82.0),
#       ('StudyInstanceUID',
#        '1.3.6.1.4.1.14519.5.2.1.5168.1900.381397737790414481604846607090'),
#       ('SeriesInstanceUID',
#        '1.3.6.1.4.1.14519.5.2.1.5168.1900.315477836840324582280843038439'),
# ...

# %%
im.meta['Modality']
# Out:
# 'CT'

# %%
im.meta.keys()
# Out:
# odict_keys(['TransferSyntaxUID', 'SOPClassUID', 'SOPInstanceUID', 'StudyDate', 'SeriesDate', 'ContentDate', 'StudyTime', 'SeriesTime', 'ContentTime', 'Modality', 'Manufacturer', 'StudyDescription', 'SeriesDescription', 'PatientName', 'PatientID', 'PatientBirthDate', 'PatientSex', 'PatientWeight', 'StudyInstanceUID', 'SeriesInstanceUID', 'SeriesNumber', 'AcquisitionNumber', 'InstanceNumber', 'ImagePositionPatient', 'ImageOrientationPatient', 'SamplesPerPixel', 'Rows', 'Columns', 'PixelSpacing', 'BitsAllocated', 'BitsStored', 'HighBit', 'PixelRepresentation', 'RescaleIntercept', 'RescaleSlope', 'PixelData', 'shape', 'sampling'])

# %% [markdown]
# #### Plotting images
# - Matplotlib's `imshow()` function displays 2D image data
# - Many colormaps available but often shown in grayscale `(cmap='gray')`

# %%
import matplotlib.pyplot as plt

plt.imshow(im, cmap='gray')
plt.axis('off')
plt.show()

# %% [markdown]
# #### Exercise:
# - Load images

# %%
# Import ImageIO
import imageio

# Load "chest-220.dcm"
im = imageio.v2.imread('chest-220.dcm')

# Print image attributes
print('Image type:', type(im))
print('Shape of image array:', im.shape)
# Out:
# Image type: <class 'imageio.core.util.Array'>
# Shape of image array: (512, 512)
# C:\Users\USER\AppData\Local\Temp\ipykernel_13976\1486248475.py:5: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   im = imageio.imread('chest-220.dcm')

# %%
# Import ImageIO and load image
import imageio
im = imageio.v2.imread('chest-220.dcm')

# Print the available metadata fields
print(im.meta.keys())
# Out:
# odict_keys(['TransferSyntaxUID', 'SOPClassUID', 'SOPInstanceUID', 'StudyDate', 'SeriesDate', 'ContentDate', 'StudyTime', 'SeriesTime', 'ContentTime', 'Modality', 'Manufacturer', 'StudyDescription', 'SeriesDescription', 'PatientName', 'PatientID', 'PatientBirthDate', 'PatientSex', 'PatientWeight', 'StudyInstanceUID', 'SeriesInstanceUID', 'SeriesNumber', 'AcquisitionNumber', 'InstanceNumber', 'ImagePositionPatient', 'ImageOrientationPatient', 'SamplesPerPixel', 'Rows', 'Columns', 'PixelSpacing', 'BitsAllocated', 'BitsStored', 'HighBit', 'PixelRepresentation', 'RescaleIntercept', 'RescaleSlope', 'PixelData', 'shape', 'sampling'])
# C:\Users\USER\AppData\Local\Temp\ipykernel_13976\2922969538.py:3: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   im = imageio.imread('chest-220.dcm')

# %%
# Draw the image with greater contrast
plt.imshow(im, cmap='gray', vmin=-200, vmax=200)

# Render the image
plt.show()

# %%
# Draw the image with greater contrast
plt.imshow(im, cmap='gray', vmin=-200, vmax=200)
# Remove axis ticks and labels
plt.axis('off')

# Render the image
plt.show()

# %% [markdown]
# ## N - dimensional images
# - Images of all shapes and sizes
#     - N-dimensional images are stacks of arrays

# %%
import imageio
import numpy as np 
im1 = imageio.v2.imread('chest-220.dcm')
im2 = imageio.v2.imread('chest-221.dcm')
im3 = imageio.v2.imread('chest-224.dcm')

im1.shape
# Out:
# (512, 512)

# %%
vol = np.stack([im1, im2, im3])
vol.shape
# Out:
# (3, 512, 512)

# %% [markdown]
# ### Loading volumes directly
# `imageio.volread()`
# - read multiple-dimensional data directly
# - assemble a volume from multiple images

# %%
import os 
os.listdir('chest-data-1')
# Out:
# ['chest-220.dcm',
#  'chest-221.dcm',
#  'chest-222.dcm',
#  'chest-224.dcm',
#  'chest-225.dcm']

# %%
import imageio
vol = imageio.v2.volread('chest-data-1', format='DICOM')
vol.shape
# Out:
# Reading DICOM (examining files): 1/5 files (20.0%5/5 files (100.0%)
#   Found 1 correct series.
# Reading DICOM (loading data): 5/5  (100.0%)
# (5, 512, 512)

# %% [markdown]
# #### Shape, sampling, and field of view
# - Image shape: number of elements along each axis

# %%
import imageio
vol = imageio.v2.volread('chest-data-1', format='DICOM')
# Image shape (in voxels)
n0, n1, n2 = vol.shape
n0, n1, n2
# Out:
# Reading DICOM (examining files): 1/5 files (20.0%5/5 files (100.0%)
#   Found 1 correct series.
# Reading DICOM (loading data): 5/5  (100.0%)
# (5, 512, 512)

# %% [markdown]
# - *Sampling rate*: physical space covered by each element

# %%
# Sampling rate (in mm)
d0, d1, d2 = vol.meta['sampling']
d0, d1, d2
# Out:
# (3.269999999999996, 0.976562, 0.976562)

# %%
# Field of view (in mm)
n0 * d0, n1 * d1, n2 * d2
# Out:
# (16.34999999999998, 499.999744, 499.999744)

# %% [markdown]
# #### Exercise:
# - Stack images

# %%
# Import ImageIO and NumPy
import imageio
import numpy as np

# Read in each 2D image
im1 = imageio.imread('chest-220.dcm')
im2 = imageio.imread('chest-221.dcm')
im3 = imageio.imread('chest-222.dcm')

# Stack images into a volume
vol = np.stack([im1, im2, im3], axis=0)
print('Volume dimensions:', vol.shape)
# Out:
# Volume dimensions: (3, 512, 512)
# C:\Users\USER\AppData\Local\Temp\ipykernel_13976\467446375.py:6: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   im1 = imageio.imread('chest-220.dcm')
# C:\Users\USER\AppData\Local\Temp\ipykernel_13976\467446375.py:7: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   im2 = imageio.imread('chest-221.dcm')
# ...

# %%
# Import ImageIO
import imageio

# Load the "tcia-chest-ct" directory
vol = imageio.v2.volread('chest-data-1', format='DICOM')

# Print image attributes
print('Available metadata:', vol.meta.keys())
print('Shape of image array:', vol.shape)
# Out:
# Reading DICOM (examining files): 1/5 files (20.0%5/5 files (100.0%)
#   Found 1 correct series.
# Reading DICOM (loading data): 5/5  (100.0%)
# Available metadata: odict_keys(['TransferSyntaxUID', 'SOPClassUID', 'SOPInstanceUID', 'StudyDate', 'SeriesDate', 'ContentDate', 'StudyTime', 'SeriesTime', 'ContentTime', 'Modality', 'Manufacturer', 'StudyDescription', 'SeriesDescription', 'PatientName', 'PatientID', 'PatientBirthDate', 'PatientSex', 'PatientWeight', 'StudyInstanceUID', 'SeriesInstanceUID', 'SeriesNumber', 'AcquisitionNumber', 'InstanceNumber', 'ImagePositionPatient', 'ImageOrientationPatient', 'SamplesPerPixel', 'Rows', 'Columns', 'PixelSpacing', 'BitsAllocated', 'BitsStored', 'HighBit', 'PixelRepresentation', 'RescaleIntercept', 'RescaleSlope', 'PixelData', 'shape', 'sampling'])
# Shape of image array: (5, 512, 512)

# %% [markdown]
# #### Advanced Plotting

# %% [markdown]
# #####  Plotting multiple images at once
# `plt.subplots`: creates a figure canvas with multiple `AxesSubplots` objects

# %%
import imageio
vol = imageio.v2.volread('chest-data-1',format='DICOM')
fig, axes = plt.subplots(nrows=1, ncols=3)
axes[0].imshow(vol[0], cmap='gray')
axes[1].imshow(vol[1], cmap='gray')
axes[2].imshow(vol[2], cmap='gray')

for ax in axes:
    ax.axis('off')
plt.show()
# Out:
# Reading DICOM (examining files): 1/5 files (20.0%5/5 files (100.0%)
#   Found 1 correct series.
# Reading DICOM (loading data): 5/5  (100.0%)

# %% [markdown]
# - Non-standard views

# %%
import imageio

vol = imageio.v2.volread('chest-data-1',format='DICOM')
view_1v2 = vol[pln, :, :]
view_1v2 = vol[pln]
view_1v2 = vol[:, row, :]
view_1v2 = vol[:, :, col]
# Out:
# Reading DICOM (examining files): 1/5 files (20.0%5/5 files (100.0%)
#   Found 1 correct series.
# Reading DICOM (loading data): 5/5  (100.0%)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[62], line 4
#       1 import imageio
#       3 vol = imageio.v2.volread('chest-data-1',format='DICOM')
# ----> 4 view_1v2 = vol[pln, :, :]
#       5 view_1v2 = vol[pln]
#
# NameError: name 'pln' is not defined

# %% [markdown]
# - Modifying the aspect ratio
# Pixels may adopt any aspect ratio: `4:1`, `16:9`, `1:1`

# %%
im = vol[:,:, 100]
d0, d1, d2 = vol.meta['sampling']
d0, d1, d2
# Out:
# (3.269999999999996, 0.976562, 0.976562)

# %%
asp = d0/ d1
asp
# Out:
# 3.3484817144226335

# %%
plt.imshow(im, cmap='gray', aspect=asp)
plt.show()

# %% [markdown]
# #### Exercise

# %%
# Import PyPlot
import matplotlib.pyplot as plt

# Initialize figure and axes grid
fig, axes = plt.subplots(nrows=2, ncols=1)

# Draw an image on each subplot
axes[0].imshow(im1, cmap='gray')
axes[1].imshow(im2, cmap='gray')

# Remove ticks/labels and render
axes[0].axis('off')
axes[1].axis('off')
plt.show()

# %% [markdown]
# - Slice 3D images

# %%
# Plot the images on a subplots array 
fig, axes = plt.subplots(nrows=1, ncols=4)

# Loop through subplots and draw image
for ii in range(4):
    im = vol[ii, :, :]
    axes[ii].imshow(im, cmap='gray')
    axes[ii].axis('off')
    
# Render the figure
plt.show()
