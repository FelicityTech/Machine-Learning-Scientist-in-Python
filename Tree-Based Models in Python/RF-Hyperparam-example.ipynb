# %%
# Import RandomForestRegressor
from sklearn.ensemble import RandomForestRegressor


# Set seed for reproducibility
SEED = 1
# Instantiate a random forest s regressor 'rf'
rf = RandomForestRegressor(random_state=SEED)

# %%
# Inspect rf's hyperparameters
rf.get_params()

# %%
# Basic Import
from sklearn.metrics import mean_squared_error as MSE
from sklearn.model_selection import GridSearchCV
# Define a grid of hyperparameter 'param_rf'
params_rf = {
    'n_estimators': [300, 400, 500],
    'max_depth': [4, 6, 8],
    'min_samples_leaf': [0.1, 0.2],
    'max_features': ['log2', 'sqrt']
}

# Instantiate 'grid_rf'
grid_rf = GridSearchCV(estimator=rf, param_grid=params_rf, CV=3, scoring='neg_mean_squared_error', verbose=1, n_jobs=-1)

# %%
# Fit 'grid_rf' to the training set
grid_rf.fit(X_train, y_train)

# %%
# Extract the best hyperparameters from 'grid_rf'
best_hyperparams = grid_rf.best_params_

print('Best hyperparameters:\n', best_hyperparams)

# %% [markdown]
# #### Evaluation the best model performance

# %%
# Extract the best model from 'grid_rf'
from Random_forest import rmse_test


best_model = grid_rf.best_estimator_
# Predict the test set labels
y_pred = best_model.predict(X_test)
# Evaluate the test se RMSE
rmse_test = MSE(y_test, y_pred)**(1/2)

# Print the test set RMSE
print('Test se RMSE of rf: {:.2f}'.format(rmse_test))
